# %% [markdown]
# # Free data on quoted companies - Yahoo Finance API
# - Including derivative data such as call/put options

# %% [markdown]
# Source:
# In this post, I’m going to explore the use of integrating with the Yahoo Finance API via Python code.
# https://towardsdatascience.com/free-stock-data-for-python-using-yahoo-finance-api-9dafd96cad2e?gi=a850556ad9ab
#
# Download Financial Dataset Using Yahoo Finance in Python | A Complete Guide
# https://www.analyticsvidhya.com/blog/2021/06/download-financial-dataset-using-yahoo-finance-in-python-a-complete-guide/
#
# Download options data
# https://algotrading101.com/learn/yfinance-guide/
#
# Webscrapping Options Data with Python and YFinance
# https://medium.com/@txlian13/webscrapping-options-data-with-python-and-yfinance-e4deb0124613

# %% [markdown]
# # Plot historical prices

# %%
# Installation of missing libraries via pip
# !pip install yfinance
# !pip install yahoofinancials
# Out:
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\programdata\anaconda3\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\programdata\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# very easy module to work with
import yfinance as yf

# a bit more advanced
from yahoofinancials import YahooFinancials

import datetime as dt
from datetime import date

# %% [markdown]
# # Variables

# %%
start_date = dt.datetime(2019,1,1)
end_date = date.today()

################# CHANGE THE SYMBOL HERE #################
# e.g. MSFT, 
stock_symbol = 'CBA.AX'

# %% [markdown]
# # Use yfinance

# %%
aapl_df = yf.download(stock_symbol,
                      start=start_date,
                      end=end_date,
                      progress=False,
)

# %%
aapl_df = yf.download(stock_symbol)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
aapl_df.head()
# Out:
#                Open     High      Low    Close  Adj Close  Volume
# Date
# 1991-10-01  6.78662  6.78662  6.78662  6.78662   1.341875     0.0
# 1991-10-02  6.78662  6.78662  6.78662  6.78662   1.341875     0.0
# 1991-10-03  6.78662  6.78662  6.78662  6.78662   1.341875     0.0
# 1991-10-04  6.78662  6.78662  6.78662  6.78662   1.341875     0.0
# 1991-10-07  6.78662  6.78662  6.78662  6.78662   1.341875     0.0

# %%
aapl_df = yf.download('AMZN')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ticker = yf.Ticker(stock_symbol)
aapl_df = ticker.history(period="5y")
aapl_df['Close'].plot(title=" stock price")

# %%
# show next event (earnings, etc)
ticker.calendar
# Out:
#                                Value
# Earnings Date    2022-02-09 10:59:00
# Earnings Average                 NaT
# Earnings Low                     NaT
# Earnings High                    NaT
# Revenue Average                  NaT
# Revenue Low                      NaT
# Revenue High                     NaT

# %%
# get the weekly highs and lows
symbol_historical = ticker.history(period="max", interval="1wk")
symbol_historical
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 1991-09-30    1.341875    1.341875    1.341875    1.341875         0.0
# 1991-10-07    1.341875    1.341875    1.341875    1.341875         0.0
# 1991-10-14    1.341875    1.341875    1.341875    1.341875         0.0
# 1991-10-21    1.341875    1.341875    1.341875    1.341875         0.0
# 1991-10-28    1.341875    1.484375    1.341875    1.484375         0.0
# ...                ...         ...         ...         ...         ...
# 2021-11-01  105.680000  109.949997  104.750000  109.709999  10478319.0
# 2021-11-08  110.000000  110.190002  106.430000  108.120003   8318551.0
# 2021-11-15  108.029999  108.110001   97.459999   97.809998  20932648.0
# 2021-11-22   97.820000   98.330002   95.650002   97.180000   7706675.0
# 2021-11-25   96.870003   97.059998   95.669998   95.769997   2390804.0
#
#             Dividends  Stock Splits
# Date
# 1991-09-30        0.0           0.0
# ...

# %%
# show actions (dividends, splits)
ticker.actions
# Out:
#             Dividends  Stock Splits
# Date
# 
ticker.major_holders
# Out:
#         0                                      1
# 0   0.41%        % of Shares Held by All Insider
# 1  19.84%       % of Shares Held by Institutions
# 2  19.92%        % of Float Held by Institutions
# 3     369  Number of Institutions Holding Shares

# %%
# show institutional holders
ticker.institutional_holders
# Out:
#                                               Holder    Shares Date Reported  \
# 0  Vanguard International Stock Index-Total Intl ...  22610533    2021-07-31
# 1  Vanguard Tax Managed Fund-Vanguard Developed M...  11796362    2021-06-30
# 2                         iShares Core MSCI EAFE ETF   8635615    2021-09-30
# 3                              iShares MSCI Eafe ETF   5909496    2021-09-30
# 4                  Fidelity International Index Fund   4040750    2021-09-30
# 5  JP Morgan ETF Tr-BetaBuilders Developed Asia e...   3631980    2021-09-30
# 6  Vanguard Intl Equity Index Fds-FTSE All World ...   3324177    2021-07-31
# 7                        iShares MSCI Eafe Value ETF   3229410    2021-09-30
# 8           Fidelity Series International Value Fund   2621890    2021-09-30
# 9  Schwab Strategic Tr-Schwab International Equit...   2342160    2021-08-31
#
#     % Out       Value
# 0  0.0133  2253139613
# 1  0.0069  1178102672
# 2  0.0051   900953712
# 3  0.0035   616537717
# ...

# %%
# show balance sheet
ticker.balance_sheet
# Out:
#                                     2021-06-30    2020-06-30    2019-06-30  \
# Intangible Assets                 1.625000e+09  1.607000e+09  1.991000e+09
# Total Liab                        1.013244e+12  9.435330e+11  9.068530e+11
# Total Stockholder Equity          7.871300e+10  7.193300e+10  6.959400e+10
# Minority Interest                 5.000000e+06  5.000000e+06  5.500000e+07
# Other Current Liab                7.331000e+09  9.681000e+09  2.103200e+10
# Total Assets                      1.091962e+12  1.015471e+12  9.765020e+11
# Common Stock                      3.854600e+10  3.828200e+10  3.828300e+10
# Other Current Assets              7.055000e+09  1.109600e+10  2.315600e+10
# Retained Earnings                 3.704400e+10  3.113600e+10  2.921500e+10
# Other Liab                        5.772000e+09  5.508000e+09  4.898000e+09
# Good Will                         5.317000e+09  5.284000e+09  5.974000e+09
# ...

# %%
# show balance sheet
ticker.quarterly_balance_sheet
# Out:
#                                     2021-06-30    2021-03-31    2020-12-31  \
# Intangible Assets                 1.625000e+09  1.625000e+09  1.674000e+09
# Total Liab                        1.013244e+12  1.013244e+12  9.827310e+11
# Total Stockholder Equity          7.871300e+10  7.871300e+10  7.499800e+10
# Minority Interest                 5.000000e+06  5.000000e+06  5.000000e+06
# Other Current Liab                7.331000e+09  7.331000e+09  7.600000e+08
# Total Assets                      1.091962e+12  1.091962e+12  1.057734e+12
# Common Stock                      3.854600e+10  3.854600e+10  3.854600e+10
# Other Current Assets              7.055000e+09  7.055000e+09  2.031400e+10
# Retained Earnings                 3.704400e+10  3.704400e+10  3.429400e+10
# Other Liab                        5.772000e+09  5.772000e+09  2.085700e+10
# Good Will                         5.317000e+09  5.317000e+09  5.269000e+09
# ...

# %%
# show cashflow
ticker.cashflow
# Out:
#                                              2021-06-30    2020-06-30  \
# Investments                                8.320000e+08 -1.800000e+07
# Change To Liabilities                      2.370000e+08  7.600000e+07
# Total Cashflows From Investing Activities  8.710000e+08  3.749000e+09
# Net Borrowings                             2.235600e+10 -2.301600e+10
# Total Cash From Financing Activities       7.950000e+10  3.853500e+10
# Change To Operating Activities            -2.922600e+10 -4.024400e+10
# Issuance Of Stock                          5.000000e+06  9.300000e+07
# Net Income                                 1.018100e+10  9.592000e+09
# Change In Cash                             6.002900e+10  1.034100e+10
# Repurchase Of Stock                       -7.100000e+07 -6.500000e+07
# Effect Of Exchange Rate                   -4.650000e+08  1.700000e+07
# Total Cash From Operating Activities      -1.987700e+10 -3.196000e+10
# ...

# %%
# show cashflow
ticker.quarterly_cashflow
# Out:
#                                              2021-06-30    2021-03-31  \
# Investments                                4.160000e+08  4.160000e+08
# Change To Liabilities                      1.185000e+08  1.185000e+08
# Total Cashflows From Investing Activities  2.385000e+08  2.385000e+08
# Net Borrowings                             1.767850e+10  1.767850e+10
# Total Cash From Financing Activities       4.605250e+10  4.605250e+10
# Change To Operating Activities            -2.800700e+10 -2.800700e+10
# Issuance Of Stock                          2.500000e+06  2.500000e+06
# Net Income                                 2.652000e+09  2.652000e+09
# Change In Cash                             2.152900e+10  2.152900e+10
# Repurchase Of Stock                       -3.550000e+07 -3.550000e+07
# Effect Of Exchange Rate                    7.290000e+08  7.290000e+08
# Total Cash From Operating Activities      -2.549100e+10 -2.549100e+10
# ...

# %%
# show earnings
ticker.earnings
# Out:
#           Revenue     Earnings
# Year
# 2018  23240000000   9329000000
# 2019  22304000000   8566000000
# 2020  21500000000   9592000000
# 2021  23972000000  10181000000

# %%
# show earnings
ticker.quarterly_earnings
# Out:
#             Revenue    Earnings
# Quarter
# 3Q2020   5569000000  2438500000
# 4Q2020   5569000000  2438500000
# 1Q2021   6417000000  2652000000
# 2Q2021   6417000000  2652000000

# %%
# show sustainability
ticker.sustainability
# Out:
#                           Value
# 2021-9
# palmOil                   False
# controversialWeapons      False
# gambling                  False
# socialScore               13.59
# nuclear                   False
# furLeather                False
# alcoholic                 False
# gmo                       False
# catholic                  False
# socialPercentile           None
# peerCount                   165
# governanceScore           11.38
# environmentPercentile      None
# animalTesting             False
# tobacco                   False
# totalEsg                     26
# highestControversy            4
# esgPerformance         AVG_PERF
# coal                      False
# pesticides                False
# adult                     False
# percentile                 44.9
# peerGroup                 Banks
# smallArms                 False
# environmentScore           1.04
# governancePercentile       None
# militaryContract          False

# %%
# show analysts recommendations
#ticker.recommendations.tail(5)

# %%
# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
ticker.isin
# Out:
# '-'

# %%
ticker.info['dividendRate']
# Out:
# 4

# %%
# If you want the average volume over the last 24 hours do:
ticker.info["averageVolume"]
# Out:
# 2902793

# %%
# To find the current volume do:
ticker.info["volume"]
# Out:
# 2390804

# %%
# To get the market cap, use:
ticker.info["marketCap"]
# Out:
# 163420962816

# %%
# And finally if you want the average volume over the last 10 days:
ticker.info["averageVolume10days"]
# Out:
# 3238350

# %%
ticker.info["fiftyTwoWeekHigh"]
# Out:
# 110.19

# %%
ticker.info
# Out:
# {'zip': '2000',
#  'sector': 'Financial Services',
#  'fullTimeEmployees': 44375,
# ...

# %% [markdown]
# # How to use yahoofinancials?

# %%
yahoo_financials = YahooFinancials('AAPL')
data = yahoo_financials.get_historical_price_data(start_date='2019-01-01', 
                                                  end_date='2019-12-31', 
                                                  time_interval='weekly')
aapl_df = pd.DataFrame(data['AAPL']['prices'])
aapl_df = aapl_df.drop('date', axis=1).set_index('formatted_date')
aapl_df.head()
# Out:
#                      high        low       open      close     volume  \
# formatted_date
# 2019-01-01      39.712502  35.500000  38.722500  36.982498  966947200
# 2019-01-08      38.632500  37.130001  37.389999  37.500000  725470000
# 2019-01-15      39.470001  37.512501  37.567501  39.205002  491411200
# 2019-01-22      39.532501  37.924999  39.102501  39.075001  554774800
# 2019-01-29      42.915001  38.527500  39.062500  42.812500  830400800
#
#                  adjclose
# formatted_date
# 2019-01-01      35.901775
# 2019-01-08      36.404144
# 2019-01-15      38.059330
# 2019-01-22      37.933132
# 2019-01-29      41.561413

# %%
yahoo_financials.get_stock_quote_type_data()
# Out:
# {'AAPL': {'exchange': 'NMS',
#   'shortName': 'Apple Inc.',
#   'longName': 'Apple Inc.',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-18000000',
#   'quoteType': 'EQUITY',
#   'symbol': 'AAPL',
#   'messageBoardId': 'finmb_24937',
#   'market': 'us_market'}}

# %% [markdown]
# get_stock_quote_type_data() – This method returns a lot of generic information about a stock which is similar to the yfinance info() function. The output is something like this.
#
# get_summary_data() – This method returns a summary of the whole company along with useful data like the beta value, price to book value, and more.
#
# get_stock_earnings_data() – THis method returns the information on the quarterly and yearly earnings of the company along with the next date when the company will report its earnings.
#
# get_financial_stmts() – This is another useful method to retrieve financial statements of a company which is useful for the analysis of a stock
#
# get_historical_price_data() – This is a method similar to the download() or Ticker() function to get the prices of stock with start_date, end_date and interval ranges.

# %%
yahoo_financials = YahooFinancials('BTC-USD')
data=yahoo_financials.get_historical_price_data("2010-07-10", "2021-10-26", "monthly")
btc_df = pd.DataFrame(data['BTC-USD']['prices'])
btc_df = btc_df.drop('date', axis=1).set_index('formatted_date')
btc_df.tail(3)
# Out:
#                         high           low          open         close  \
# formatted_date
# 2021-08-01      50482.078125  37458.003906  41460.843750  47166.687500
# 2021-09-01      52853.765625  39787.609375  47099.773438  43790.894531
# 2021-10-01      66930.390625  43320.023438  43816.742188  61318.957031
#
#                        volume      adjclose
# formatted_date
# 2021-08-01      1014674184428  47166.687500
# 2021-09-01      1102139678824  43790.894531
# 2021-10-01      1153077903534  61318.957031

# %%
btc_df['close'].plot(title="stock price")

# %% [markdown]
# # Download options data using the yfinance library

# %%
# show options expirations
ticker.options
# Out:
# ()

# %%
ticker.options[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-b9a64e4cd8a7> in <module>
# ----> 1 ticker.options[2]
#
# IndexError: tuple index out of range

# %%
# get option chain calls data for specific expiration date
opt = ticker.option_chain(date='2022-02-16')
opt.calls

# %%
opt.puts

# %%
# get option chain for specific expiration
opt = ticker.option_chain('2022-02-16')
# data available via: opt.calls, opt.puts
opt

# %%
# get option chain for specific expiration
opt = aapl_df.option_chain('2022-02-16')
# data available via: opt.calls, opt.puts
opt
